# %% [markdown]
# # Phase 1: Text Extraction & Naive Chunking
#
# This notebook covers the experiments for reading PDFs and splitting them into manageable chunks.
#
# ## Objectives:
# - Use `pdfplumber` (or `PyPDF2`) to extract text.
# - Use LangChain's `RecursiveCharacterTextSplitter` to chunk the text.
# - Visually verify chunk overlap.

# %%
# !pip install pdfplumber langchain

# %%
import pdfplumber
from langchain.text_splitter import RecursiveCharacterTextSplitter

pdf_path = "../data/raw/sample.pdf"
# TODO: Open the PDF and extract text

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len,
)

# TODO: Split the extracted text and print the first few chunks
