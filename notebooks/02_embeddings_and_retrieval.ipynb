# %% [markdown]
# # Phase 2 & 3: Embeddings, Vector Store, and Retrieval
#
# This notebook covers the experiments for converting text chunks into vectors and performing similarity searches.
#
# ## Objectives:
# - Initialize an embedding model.
# - Store vectors in a local FAISS or ChromaDB index.
# - Perform nearest-neighbor search for a query.

# %%
# !pip install faiss-cpu chromadb sentence-transformers

# %%
# TODO: Initialize embedding model (e.g., via HuggingFace or OpenAI)

# %%
# TODO: Initialize vector store and add embedded chunks

# %%
query = "What is the main topic of the document?"
# TODO: Embed query, search vector store, and print top 3 matches with similarity scores
